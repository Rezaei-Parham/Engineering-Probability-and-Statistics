# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز 1401
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی بخش دوم
#             	<br/>
# 			</font>
# طراحان: محمدجواد ماهرالنقش، محمد‌مهدی ابوترابی
# 			<br/><br/>
# موعد تحویل: 14 آبان
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما خواسته می‌شود تا تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %% [markdown]
# <div style="direction:rtl">
#  نام و نام خانوادگی: پرهام رضایی
# </div>

# %% [markdown]
# <div style="direction:rtl">
#     شماره دانشجویی: 400108547
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال اول
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتافریم airquality یکی از دیتا فریم‌های biult-in است که اطلاعاتی در مورد وضعیت آب‌و‌هوای نیویورک در یک بازه‌ی زمانی می‌دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
library(ggplot2)

# %%
head(airquality)
# Out:
#   Ozone Solar.R Wind Temp Month Day
# 1 41    190      7.4 67   5     1
# 2 36    118      8.0 72   5     2
# 3 12    149     12.6 74   5     3
# 4 18    313     11.5 62   5     4
# 5 NA     NA     14.3 56   5     5
# 6 28     NA     14.9 66   5     6

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         الف)
# به کمک boxplot‌ها یک نمودار مناسب ارائه دهید که وضعیت دما (temp) را بر حسب ماه‌های مختلف نشان دهد.
#      </font>
# </div>

# %%
u <- ggplot(data=airquality, aes(group=Month,x=Month, y=Temp,fill="Yellow"))
u + geom_boxplot() + theme(axis.title.x = element_text(colour="DarkGreen",size=20))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) بخش الف را برای میانگین باد و میانگین غلظت اوزون و میانگین تابش خورشید بر حسب ماه‌های مختلف تکرار کنید و نتایج خود را از این 4 نمودار شرح دهید.
#      </font>
# </div>

# %%
uO <- boxplot(Ozone~Month, data = airquality)
uW <- boxplot(Wind~Month, data=airquality)
uS <- boxplot(Solar.R~Month, data=airquality)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# #نتایج
# دما و باد تاثیر برعکس دارند یعنی می‌توان مشاهده کرد که با افزایش دما در ماه های نزدیک ۷ میزان باد کاهش یافته است. همچنین میزان اوزون نیز مشابه دما افزایش و کاهش داشته یعنی تاثیر مستقیم دارد و تابش خورشید هم در ماهی که اوزون و دما زیاد شده است از حد سایر ماه ها افزایش داشته ولی در مابقی میانگین نسبتا ثابتی داشته. اما مینیمم آن به طور نسبت مستقیم با دما تغییر کرده است.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ج) به کمک boxplot‌ها رنج اعداد مختلف در پارامتر‌های متفاوت را در این دیتاست را بررسی کنید.
#      </font>
# </div>

# %%
cat("Ozone ranges and data\n\n")
uO$stats
cat("Wind ranges and data\n\n")
uW$stats
cat("Solar.R ranges and data\n\n")
uS$stats
boxplot(airquality,col=rgb(0.1,0.1,0.7,0.6)) # showing all in the same plot
# Out:
# Ozone ranges and data
#      [,1] [,2] [,3] [,4] [,5]
# [1,]  1   12     7    9   7
# [2,] 11   20    35   28  16
# [3,] 18   23    60   52  23
# [4,] 32   37    80   84  36
# [5,] 45   39   135  168  47
# Wind ranges and data
#      [,1]  [,2] [,3] [,4] [,5]
# [1,]  5.70  4.6  4.1  2.3  2.8
# [2,]  8.90  8.0  6.9  6.6  7.4
# [3,] 11.50  9.7  8.6  8.6 10.3
# [4,] 14.05 11.5 10.9 11.2 12.6
# [5,] 20.10 16.1 14.9 15.5 16.6
# Solar.R ranges and data
#      [,1]  [,2]  [,3] [,4]  [,5]
# [1,]   8.0  31.0  48   24.0  14
# [2,]  72.0 127.0 175   99.0 112
# [3,] 194.0 188.5 253  197.5 192
# [4,] 284.5 273.0 273  233.0 236
# [5,] 334.0 332.0 314  273.0 259
# plot without title

# %% [markdown]
# برای انرژی خورشیدی داریم که باتوجه به خطوط پایین و بالای چارک ها که در باکس پلات رسم شده، رنج بین ۰ (در حقیقت ۷ که با امیت ان ای ها بدست می آید) و حد بالایی بین ۳۰۰ و ۴۰۰ (در حقیقت ۳۳۴ با امیت ان ای ها) می‌باشد. همچنین باد بین نزدیک ۰ (که درواقع ۱.۷) تا حدود ۲۰ (درواقع ۲۰.۷) می باشد و همچنین اوزون از نزدیکی ۰ (درواقع ۱) تا مقدار حد فاصل ۱۵۰ و ۲۰۰ (درواقع ۱۶۸) و دما از مقدار کمتر از ۶۰ که درواقع ۵۶ است تا حدی بیشتر از ۹۰ که ۹۷ است.
# همچنین همانطور که از محور ها و دیتا نمایان است، رنج ماه ها از ۵ تا ۹ می‌باشد.
# رنج های دقیق کران بالا و پایین هر جدول اند، دیتاهای اشاره شده در این متن با احتساب داده های پرت اند

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# د) به کمک نمودار scatter نمودار میانگین غلظت اوزون بر حسب دما را رسم کنید و آن را تحلیل کنید.
#      </font>
# </div>

# %%
w <- ggplot(data=airquality, aes(x=Temp, y=Ozone, colour=Ozone))
w + stat_summary(fun=mean, geom = "point") #Average

w + geom_point(aes(color=Ozone)) #Ozone itself
# Out:
# Warning message:
# “Removed 37 rows containing non-finite values (`stat_summary()`).”
# Warning message:
# “Removed 37 rows containing missing values (`geom_point()`).”
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ه) نمودار نقطه‌ای (scatter) را براساس ویژگی‌های جذر میانگین غلظت اوزون و ماه و باد رسم کنید. سعی کنید نمودار رسم شده اطلاعات را به خوبی نشان دهد. نتایج خود را بیان کنید. (به وابستگی میان متغیر‌ها توجه کنید.)
#      </font>
# </div>

# %%
a <- function(x) return (sqrt(x))
u <- ggplot(data=airquality, aes(x=Wind, y=Ozone, colour = Month))
u + stat_summary(fun=sqrt, geom="point", aes(color=paste("month",Month)))
# Out:
# Warning message:
# “Removed 37 rows containing non-finite values (`stat_summary()`).”
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# و) نمودار هیستوگرام برای باد و  تابش خورشید رسم کنید، این دو نمودار را با هم و با نمودار توزیع نرمال مقایسه کنید و نتیجه‌ی خود را آن بیان کنید.
#      </font>
# </div>

# %%
# o <- ggplot(data=airquality, aes(x=Wind))
# o + geom_histogram(binwidth=10, aes(fill="violet"), col="black")
# o <- ggplot(data=airquality, aes(x=Solar.R))
# o + geom_histogram(binwidth=10, aes(fill="violet"), col="black")
h <- hist(airquality$Wind, breaks=10)
hist(airquality$Solar.R, breaks=20)
rnorm(10000, mean=0, sd=1) -> y_standard_normal
hist(y_standard_normal, col="violet")
rnorm(10000,mean=250,sd=1) -> mean_250_normal
hist(mean_250_normal, col="green")
# Out:
# Plot with title “Histogram of airquality$Wind”
# Plot with title “Histogram of airquality$Solar.R”
# Plot with title “Histogram of y_standard_normal”
# Plot with title “Histogram of mean_250_normal”

# %% [markdown]
# از لحاظ میزان شباهت، مطابق نمودارهای کشیده شده، با توجه به میزان داده بررسی شده توزیع باد به نظر حدودا از توزیع نورمال پیروی می‌کند. توزیع تابش خورشیدی ولی تقارن لازم را کمتر دارد و امید ریاضی آن نزدیک به ۲۵۰ است که با نمودار کشیده شده برای توزیع نرمال با چنین امید ریاضی و واریانس یک کمی عدم پیروی دارد.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال دوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#         در یک فرایند پواسون زمان بین دو اتفاق از یک توزیع نمایی پیروی می‌کند. اگر بخواهیم زمان اتفاق n‌ام را پیش‌بینی کنیم از توزیع گاما استفاده می‌کنیم.
#         $$T_n=\sum_{i=1}^n{X_i},\  X_i  s\ are\ i.i.d\ and\ X_i\sim Exp(\lambda)$$
#         $$T_n\sim Gamma(n, \lambda)$$
# حال فرض کنید فاصله بین ورود مشتریان به یک رستوران از توزیع نمایی پیروی می‌کند به طوری که در هر دقیقه پنج مشتری وارد می‌شوند.
#         <br>
#         الف)
#  2000  نمونه تصادفی برای زمان بین ورود مشتریان تولید کنید و نمودارهای هیستوگرام داده‌های تولیدشده و چگالی توزیع آن را در یک نمودار رسم کنید. نمودار هیستوگرام شما باید چگالی احتمال را برای هر نمونه را نشان دهد.
#             </font>
# </div>
#     </font>
# </div>

# %%
rexp(2000, rate=5) -> data_exp
hist(data_exp, col="red", breaks=40,freq=F)
lines(density(data_exp))
# Out:
# Plot with title “Histogram of data_exp”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ب)
#         بی‌حافظگی توزیع نمایی را با داده‌های تولید شده در قسمت قبل را با استفاده از داده‌های تولید شده در قسمت قبل و رسم نمودار به همان شکل نشان دهید.
#      </font>
# </div>

# %%
data_exp = data_exp[data_exp > 0.3]
hist(data_exp-0.3,breaks=40,freq=F) #shift 0.3 to zero
lines(density(data_exp-0.3), col="red")
# Out:
# Plot with title “Histogram of data_exp - 0.3”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج)
#        با تولید n=10 متغیرتصادفی نمایی، ویژگی گفته شده در صورت سوال را بررسی کنید. برای این‌کار می‌توانید برای شبیه‌سازی هر متغیرتصادفی مانند قسمت الف عمل کنید.
#      </font>
# </div>

# %%
expsum = rexp(2000, 5)
for (i in seq(1,9,by=1)){ 
  expsum + rexp(2000, 5) -> expsum
}
plot(density(expsum))
lines(density(rgamma(n=2000,10,rate=5)), col="violet")
# Out:
# Plot with title “density.default(x = expsum)”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال سوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     دیتاست مربوط به درآمد در پیوست موجود است. <br>
#     الف) به وسیلۀ دستور read.csv اطلاعات دیتاست را بخوانید. (دیتاست adult.csv)
#             </font>
# </div>
#     </font>
# </div>

# %%
adult <- read.csv("adult.csv")

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         نمودار مربوط به درآمد را برحسب سن/جنسیت به کمک نمودارهای زیر بکشید.
#      </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          ب) نمودار Bar Plot (درآمد برحسب جنسیت و سن)
#      </font>
# </div>

# %%
ggplot(adult, aes(x=income, y=age, fill=gender)) +
  geom_bar(stat="identity", position=position_dodge())
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         ج) نمودار Scatter Plot
#      </font>
# </div>

# %%
w <- ggplot(data=adult, aes(x=income, y=age, colour=gender))
w + geom_point(size=1) + coord_flip()
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         د) نمودار Histogram (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
t <- ggplot(data=adult, aes(x=age))
t + geom_histogram(binwidth=5, aes(fill=gender), colour="Black") # without income
t + geom_histogram(binwidth=5, aes(fill=gender, colour=income)) #with income
# Out:
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#        ه) نمودار Density Plot (مربوط به سن که اطلاعات زن و مرد در یک نمودار به طور تلفیقی باشد)
#      </font>
# </div>

# %%
t <- ggplot(data=adult, aes(x=age))
t + geom_density(aes(fill=gender),position="stack") # without income and with stack
t + geom_density(aes(fill=gender, color=income)) # with income without stacking
# Out:
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#          و) نمودار Trend Plot
#      </font>
# </div>

# %%
w <- ggplot(data=adult, aes(x=age, y= income))
w + geom_point(stat="identity",size=1, aes(colour=gender)) + geom_smooth(aes(group=gender,color=gender))
# Out:
# `geom_smooth()` using method = 'gam' and formula = 'y ~ s(x, bs = "cs")'
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#              سوال چهارم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
# 	<font face="XB Zar" size=5>
#     نمودار توزیع های احتمالی زیر را با توجه به به پارامترهای داده شده رسم کنید. <br> الف) نمودار توزیع پوآسون (در بازۀ 0 تا 50 با پارامتر 10)
#             </font>
# </div>
#     </font>
# </div>

# %%
y<-dpois(x=seq(0,50),lambda=10)
u <- data.frame(seq(0,50),y)
s <- ggplot(data=u, aes(x=seq(0,50),y=y, colour="black")) + geom_point(size=2) + geom_line()
s
plot(y)
# Out:
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# ب) نمودار توزیع برنولی (در بازۀ 0 تا 5 با پارامتر 0.6)
#      </font>
# </div>

# %%
install.packages("Rlab")
library("Rlab")
x_d <- dbern(seq(0,5,by=1),prob=0.6)
plot(x_d,type="o")
#or using binom with n=1
plot(dbinom(seq(0,5,by=1),1,0.6),type="o")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ج) نمودار توزیع دو جمله ای (در بازۀ 0 تا 20 با پارامتر 0.2)
#     </font>
# </div>

# %%
y <- dbinom(x=seq(0,20),size=20, prob=0.2)
u <- data.frame(seq(0,20),y)
s <- ggplot(data=u, aes(x=seq(0,20),y=y, colour="black")) + geom_point(size=2) + geom_line()
s
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     د) نمودار توزیع هندسی (در بازۀ 0 تا 10 با پارامترهای p = 0.2 و n = 3)
#     </font>
# </div>

# %%
dgeom(x=seq(0,10),prob=0.2) -> dg
plot(x=seq(0,10),y=dg,type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     ه) نمودار توزیع نرمال (در بازۀ 4- تا 4)
#      </font>
# </div>

# %%
dnorm(x=seq(-4,4,by=0.05)) -> y_standard_normal
plot(seq(-4,4,by=0.05), y_standard_normal, col="violet",type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#     و) نمودار توزیع نمایی (در بازۀ 0 تا 10 با پارامتر 1.5)
#      </font>
# </div>

# %%
exp_x = seq(0,10, by=0.1)
dexp(x=exp_x, rate=1.5) -> exp_y
plot(exp_x,exp_y,col="brown",type="o")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#      ز) نمودار توزیع یکنواخت (در بازۀ 4- تا 4)
#      </font>
# </div>

# %%
dunif(seq(-4,4,by=0.01),min=-4,max=4) -> u
plot(x=seq(-4,4,by=0.01),y=u)
runif(1000,min=-4, max=4) -> data_unif
hist(data_unif,col="violet")
# Out:
# plot without title
# Plot with title “Histogram of data_unif”
