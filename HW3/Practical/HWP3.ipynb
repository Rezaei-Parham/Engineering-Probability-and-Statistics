# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<div align=center>
# 			<font face="IranNastaliq" size=30>
# 				<p></p>
# 				<p></p>
# به نام خدا
# 				<p></p>
# 			</font>
# 			<font color=#FF7500>
# دانشگاه صنعتی شریف - دانشکده مهندسی کامپیوتر
#             </font>
# 			<p></p>
# 			<font color=blue>
# آمار و احتمال مهندسی
#             </font>
# 			<br />
# 			<br />
# پاییز ۱۴۰۱
# 		</div>
# 		<hr/>
# 		<div align=center>
# 		    <font color=red size=6>
# 			    <br />
# تمرین عملی سری سوم
#             	<br/>
# 			</font>
#             نام و نام خانوادگی: پرهام رضائی
#             <br/>
#             شماره دانشجویی: 400108547
#             <br/><br/>
#             طراحان: آیناز رفیعی، علیرضا حبیب‌زاده
# 			<br/>
# موعد تحویل: ۱۴ آذر
#                 <br/>
#                 همفکری در تمامی تمرین‌های درس توصیه می‌شود. در عین حال از شما انتظار می‌رود تمام پیاده‌سازی را به تنهایی و بدون مشاهده کد دیگران انجام دهید.
#                 <br/><br/>
#                 <font color=red>
#                 لطفا در فایل ارسالی تمام بلوک‌های کد اجرا شده و شامل نمودار‌ها و خروجی‌های لازم باشند.
#      </font>
#                 <br/>
#         </style>
# 	</font>
# </div>

# %%
options(warn=-1)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#           سوال اول
#         </font>
#         <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
#        تابعی از یک نمونه از یک متغیر تصادفی uniform بین 0 و 1 به نمونه ای از متغیر تصادفی نمایی بیابید.
#    </font>
# </div>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# پاسخ:
#
# </div>

# %%
uniToExp <- function(x) 2*exp(x)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
#        50000 نمونه از متغیر تصادفی uniform بین 0 و 1 تولید کرده و تابع بالا را روی آن اعمال کنید. پارامتر توزیع نمایی را دلخواه در نظر بگیرید ولی آن را ذکر کنید. نتیجه را بر روی نمودار نمایش دهید.
#    </font>
# </div>
#     </font>
# </div>

# %%
runif(50000,min=0,max=1) -> data_unif
#parameter is 2 stated
e <- sapply(data_unif,uniToExp)
hist(e)
# Out:
# Plot with title “Histogram of e”

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
#         <hr/>
# 10000 نمونه از متغیر تصادفی binomial با استفاده از متغیرهای تصادفی از توزیع نمایی که در مرحله‌ی قبل به دست آورده‌اید تولید کرده و بر روی نمودار نمایش دهید.<br/>
#         پارامترهای توزیع را دلخواه انتخاب کنید ولی آن‌ها را ذکر کنید.
#     </font>
# </div>

# %%
uvw <- rbinom(10000,50000,0.2)

# %%
# using X1+ ...+XN such that N is binomial
a <- list()
for(i in 1:10000){
  x <- uvw[i]
  sum=0
  j = 1

  while(uvw[i] > j){
    sum = sum + e[j]
    j = j + 1
  }
  a <- append(a,sum)
}
a <- gsub(",","",a)
a <- as.numeric(a)
hist(a)
# Out:
# Plot with title “Histogram of a”

# %%
# using Xi such that i is binomial
a <- list()
for(i in 1:10000){
  x <- uvw[i]
  a <- append(a,e[x])
}
a <- gsub(",","",a)
a <- as.numeric(a)
hist(a)
# Out:
# Plot with title “Histogram of a”

# %%
# rbin <- function(n, size, p){
#   onebin <- function(i, size, thres){
#     I <- 0L
#     repeat{
#       S <- sum(e[0:i]/(size + 1 - seq_len(I + 1)))
#       if(S > thres) break
#       I <- I + 1L
#     }
#     I
#   }
#   thres <- -log(1 - p)
#   sapply(seq_len(n), onebin, size, thres)
#   seq_len(n)
# }
# rbin(1000,1000,1)

# %% [markdown]
# <br>
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# 		<font color=#FF7500 size=6>
#             سوال دوم
#         </font>
#         <hr/>
#         <div dir = "rtl" style="direction:rtl;line-height:200%;">
#             در اتاقی یک بلندگو (فرستنده) قرار دارد که سیگنالی ارسال می‌کند
#         و همچنین سه میکروفون (گیرنده) در فواصل و جاهای مختلف قرار داده شده‌اند که این سیگنال را دریافت می‌کنند.
#             اطلاعات سیگنال ارسال شده و دریافتی بر حسب زمان در دیتاست
# data.csv
# به شما داده شده است. <br>
# داده‌ها را در یک دیتافریم لود کنید.
# </div>
#     </font>
# </div>

# %%
data <- read.csv("data.csv")

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=5>
# نمودار اطلاعات فرستنده و سه گیرنده بر حسب زمان را در یک نمودار بکشید.
#     </font>
# <div>

# %%
library(ggplot2)
q <- ggplot(data=data, aes(x=data$time)) + geom_point(aes(y=receive1)) + geom_point(aes(y=receive2),colour="Red") + geom_point(aes(y=receive3),colour="Green") + geom_point(aes(y=send), colour="khaki")
q
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#                 <hr/>
# داده‌های اندازه‌گیری شده به دلیل تفاوت و فاصله‌ی گیرنده‌ها و عوامل محیطی ممکن است دچار تغییراتی شده باشند.
# به همین منظور لازم است تا داده‌ها را نرمالایز کنیم.
# یعنی تبدیل خطی‌ای روی آن‌ها اعمال کنیم که توزیع نهایی دارای امید ریاضی صفر و انحراف معیار واحد باشد.
# $$x' = \frac{x - \bar{x}}{\sigma_x}$$
# داده‌های نرمالایز شده‌ی فرستنده و سه گیرنده را به دیتافریم اضافه کنید.
# از این به بعد تنها با داده‌های نرمالایز شده کار خواهیم کرد.
#     </font>
# </div>

# %%
norm <- function(x){
  x <- x - mean(x)
  x <- x / sqrt(var(x))
  return(x)
}

# %%
data$receive1n <- norm(data$receive1)
data$receive2n <- norm(data$receive2)
data$receive3n <- norm(data$receive3)
data$sendn <- norm(data$send)

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# برای اطمینان میانگین و واریانس داده‌های نرمالایز شده را حساب کنید.
# <br>
# آیا نتیجه با آنچه انتظار دارید یکسان است؟
#     </font>
# </div>

# %%
mean(data$receive1n)
mean(data$receive2n)
mean(data$receive3n)
mean(data$sendn)
var(data$receive1n)
var(data$receive2n)
var(data$receive3n)
var(data$sendn)
#حدودا یکسانه . واریانس ها که یک شد. میانگین هم با تقریب خوبی ۰ شده است.
# Out:
# [1] -7.879346e-16
# [1] 6.643623e-16
# [1] 2.542777e-15
# [1] -1.01522e-19
# [1] 1
# [1] 1
# [1] 1
# [1] 1

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# داده‌های نرمالایز شده‌ی گیرنده‌ها و فرستنده بر حسب زمان را در یک نمودار نشان دهید.
# </font>
# </div>

# %%
q <- ggplot(data=data, aes(x=data$time)) + geom_point(aes(y=receive1n)) + geom_point(aes(y=receive2n),colour="#FF9999") + geom_point(aes(y=receive3n),colour="Green") + geom_point(aes(y=sendn),colour="orchid2")
q
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توزیع توام داده‌های نرمالایز شده‌ی سه گیرنده با فرستنده را در نمودار یا نمودارهای مناسبی نمایش دهید.
# <br>
# <font size=3>
# (راهنمایی: جواب‌ها همگی نوعی بیضی هستند)
# </font>
# <br>
# توزیع حاشیه‌ای هر کدام از متغیرهای نرمالایز شده‌ی
# send,
# receive1,
# receive2,
# receive3
# را به صورت جداگانه یا روی همان توزیع توام نمایش دهید.
# <br>
# برای این کار می‌توانید از
# ggMarginal
# از کتابخانه‌ی
# ggExtra
# استفاده کنید. (یا نکنید)
#     </font>
# </div>

# %%
library(ggplot2)
install.packages("ggExtra")
install.packages("gridExtra")
library(ggplot2)
library(gridExtra)
library(devtools)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
print(ggplot(data,aes(x=send)) + geom_density(fill="khaki"))
print(ggplot(data,aes(x=receive1n)) + geom_density(fill="#FF9999"))
print(ggplot(data,aes(x=receive2n)) + geom_density(fill="#E69F00"))
print(ggplot(data,aes(x=receive3n)) + geom_density(fill="#56B4E9"))
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %%
install.packages("patchwork")
library(patchwork)

plot1 <- ggplot(data, aes(x = sendn, y = receive1n)) + 
  geom_point(aes(color = sendn), size = 3) + 
  scale_y_continuous(name = "receive1(normalized)") + 
  scale_x_continuous(name = "send(normalized)") + 
  theme_pubr() +
  theme(legend.position = c(0.15, 0.9)) 

dens1 <- ggplot(data, aes(x = sendn, fill = sendn)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none")

dens2 <- ggplot(data, aes(x = receive1n, fill = receive1n)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none") + 
  coord_flip()

dens1 + plot_spacer() + plot1 + dens2 + 
  plot_layout(ncol = 2, nrow = 2, widths = c(4, 1), heights = c(1, 4))
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# plot without title

# %%
plot1 <- ggplot(data, aes(x = sendn, y = receive2n)) + 
  geom_point(aes(color = sendn), size = 3) + 
  scale_y_continuous(name = "receive2(normalized)") + 
  scale_x_continuous(name = "send(normalized)") + 
  theme_pubr() +
  theme(legend.position = c(0.15, 0.9)) 

dens1 <- ggplot(data, aes(x = sendn, fill = sendn)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none")

dens2 <- ggplot(data, aes(x = receive2n, fill = receive2n)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none") + 
  coord_flip()

dens1 + plot_spacer() + plot1 + dens2 + 
  plot_layout(ncol = 2, nrow = 2, widths = c(4, 1), heights = c(1, 4))
# Out:
# plot without title

# %%
plot1 <- ggplot(data, aes(x = sendn, y = receive3n)) + 
  geom_point(aes(color = sendn), size = 3) + 
  scale_y_continuous(name = "receive3(normalized)") + 
  scale_x_continuous(name = "send(normalized)") + 
  theme_pubr() +
  theme(legend.position = c(0.15, 0.9)) 

dens1 <- ggplot(data, aes(x = sendn, fill = sendn)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none")

dens2 <- ggplot(data, aes(x = receive3n, fill = receive3n)) + 
  geom_density(alpha = 0.4) + 
  theme_void() + 
  theme(legend.position = "none") + 
  coord_flip()

dens1 + plot_spacer() + plot1 + dens2 + 
  plot_layout(ncol = 2, nrow = 2, widths = c(4, 1), heights = c(1, 4))
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         کوواریانس اطلاعات نرمالایز شده‌ی گیرنده‌ها با فرستنده را حساب کنید. (سه مقدار)
# <br>
#         مقادیر به دست‌آمده را با توزیع‌های توام که در قسمت قبل کشیدید مقایسه کنید.
#         <br>
#         (به کوواریانس بین توزیع‌های نرمالایز شده کوریلیشن نیز می‌گویند که مقداری بین منفی یک و یک است.)
# </font>
# </div>

# %%
cov(data$sendn,data$receive1n)
cov(data$sendn,data$receive2n)
cov(data$sendn,data$receive3n)
# Out:
# [1] 0.8628303
# [1] -0.00724553
# [1] -0.9967574

# %% [markdown]
# اعداد به دست آمده منطقی اند چراکه در اولی طبق نمودار با رشد هر یک دیگری نیز رشد می‌کند و برعکس در نتیجه باید کوواریانس مثبتی داشته باشد که در اعداد به دست آمده هم چنین است. در دومی شکل دایره گونه ای دارد یعنی حدودا همبستگی ندارند و رشد یکی روی رشد یا نزول دیگری تاثیر ندارد که با کوواریانس حدودا ۰ بدست آمده تطابق دارد. همچنین در آخری نیز با رشد هر یک دیگری در حال نزول است که یعنی با کوواریانس منفی به دست آمده همخوانی دارد همچنین شدت هر یک با نزدیکی قدر مطلقی به یک تطبیق دارد.

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
#         <font size=6>
#     امتیازی
# </font>
# <br>
# همان‌طور که احتمالا حدس زدید گیرنده‌ها علاوه بر آن که اطلاعات را با مقداری نویز و تضعیف شده دریافت می‌کنند آن را با تاخیر هم می‌بینند.
# یعنی نمودار داده‌های گیرنده‌ها در مقایسه با داده‌های فرستنده شیفت خورده است.
# به دلیل نویزی که در اطلاعات وجود دارد هیچوقت نقاط با شیفت دادن دقیقا روی هم قرار نمی‌گیرند.
# یک روش خوب برای پیدا کردن تاخیر بین این دو موج شیفت دادن یک موج و محاسبه‌ی کوواریانس بین این دو است تا جایی که این کوواریانس بیشینه شود.
# <br>
# (اگر نویزی وجود نداشت این مقدار برای داده‌های نرمالایز شده‌ی یک می‌بود چرا که کوواریانس یک متغیر نرمالایز شده با خودش یک است )
# <br><br>
# داده‌های گیرنده‌ی اول را به ازای جابه‌جایی‌های مضرب 5 از صفر تا 1000 میکروثانیه (نصف کل بازه‌ی زمانی) به سمت چپ شیفت دهید. سپس داده‌های 1000 میکروثانیه ابتدایی از فرستنده و گیرنده باقی می‌ماند را جدا کنید و کوواریانس این دو را محاسبه کنید.
# حال نمودار کوواریانس بر حسب شیفت را رسم کنید.
# <br><br>
# (راهنمایی:
# همیشه باید 200
# داده از میان ستون receive1 نرمالایز شده بردارید
# و کوواریانس آن را با 200 داده‌ی ابتدایی
# send نرمالایز شده حساب کنید.)
# </font>
# </div>
#
# <img src="pic1.png" width=500/>

# %%
getCov <- function(i,draw,joint){
data2 <- data
data2$time = data2$time - i
data2 <- data2[data2$time >= 0,]
data2 <- data2[data2$time <= 1000,]
data_send <- data[data$time <= 1000,]
if(draw){
# data2 = data2[data2$time > 0]
q <- ggplot(data=data2, aes(x=time)) + geom_point(aes(y=receive1n, colour = receive1n))
print(q + geom_point(data=data_send,aes(y=data_send$sendn),colour="Red"))
}
if(joint){
  plot1 <- ggplot(data_send, aes(x = data_send$sendn, y = data2$receive1n)) + 
  geom_point(aes(color = data_send$sendn), size = 3) + 
  scale_y_continuous(name = "Number of fixated faces") + 
  scale_x_continuous(name = "Population density (lg10)") + 
  theme_pubr() +
  theme(legend.position = c(0.15, 0.9)) 
print(plot1)
}
return (cov(data_send$sendn,data2$receive1n))
}

# %%
inds = 0:200
inds = inds*5
covs = list()
for (i in inds){
  covs <- append(covs,getCov(i,F,F))
}
plot(x=inds,y=covs,col="blue")
# Out:
# plot without title

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# شیفتی که در آن بیشترین کوواریانس بین داد‌های گیرنده‌ی شیفت خورده و فرستنده ایجاد می‌شود و کوواریانس بیشینه را پیدا کنید.
#     </font>
# </div>

# %%
imax = -1
cov_max = -2
for (i in 0:200){
  s <- getCov(5 * i,F,F)
  if(s > cov_max){
    cov_max = s
    imax = 5 * i
  }
}
print("best move")
print(imax)
print("best cov:")
print(cov_max)
# Out:
# [1] "best move"
# [1] 80
# [1] "best cov:"
# [1] 0.9970106

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:250%;">
# 	<font face="XB Zar" size=5>
# توزیع توام 1000 میکروثانیه اول گیرنده‌ی شیفت خورده با فرستنده را رسم کنید.
# </font>
# </div>

# %%
getCov(imax,T,F) #scatter
# Out:
# [1] 0.9970106
# plot without title

# %%
getCov(imax, F,T) #joint
# Out:
# [1] 0.9970106
# plot without title
